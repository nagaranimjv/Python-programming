# %% [markdown]
# Problem 1 : Simple Pass/Fail Checker
# Topics: Comparison Operators, Logical Operators

# %% [markdown]
# Write a Python program that:
#
# 1. Asks the user to enter marks (out of 100) for one subject.

# %%
# 1. Asks the user to enter marks (out of 100) for one subject.
marks = int(input("enter marks out of 100:"))
# Out:
# enter marks out of 100: 25

# %%
# 2. If marks >= 35 -> print "Pass", else print "Fail".
if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# Problem 2 : Pocket Money Updater
#
# Topics: Assignment Operators, Mathematical Operators

# %%
#Write a program that:
# 1. Ask the user for starting pocket money.
money = float(input("Enter the amount"))
# Out:
# Enter the amount 50

# %%
# 2. Add 200 using +=
money += 200
print("money aftet adding 200 is :",money)
# Out:
# money aftet adding 200 is : 250.0

# %%
# 3 Subtract 150 using -=
money -= 150
print("money after substracting 150 is:",money)
# Out:
# money after substracting 150 is: 100.0

# %%
# 4. Increase the remaining amount by 10% using *=
money = money + (money * 0.1)
print("money after adding 10% is :",money)
# Out:
# money after adding 10% is : 110.0

# %% [markdown]
# Problem 3 : Simple Calculator with Assignment Operators
#
# Topics: Assignment Operators

# %%
# Write a program that:
# 1. Ask the user for a number and store it in variable result.
result = int(input("enter the number:"))
print("user number is :",result)
# Out:
# enter the number: 30
# user number is : 30

# %%
# 2. Update result using:
result += 10
print("result after adding 10:",result)

result *= 2
print("result after multiply by 2 is :", result)

result -= 5
print("result after substracting 5 is:", result)

result /= 3
print("result after dividing by 3 is :", result)
# Out:
# result after adding 10: 40
# result after multiply by 2 is : 80
# result after substracting 5 is: 75
# result after dividing by 3 is : 25.0

# %% [markdown]
# Problem 4 : Username Login Checker (Membership)
#
# Topics: Membership Operators (in, not in)

# %%
# Given:
allowed = "rohan priya amit sara"

# Tasks:
# 1. Ask the user to enter a username in lowercase.
name = input("enter the name in lower case:")
# Out:
# enter the name in lower case: priya

# %%
# 2. Check if it is present using the 'in' operator.
if name in allowed:
   print("User name allowed")
else:
   print("Username not allowed")
# Out:
# User name allowed

# %% [markdown]
# Problem 5 : Identity Operators & Operator Precedence
#
# Topics: Identity Operators (is, is not), Operator Precedence

# %%
# Given:
x = 10
y = x
z = 10

# Tasks:
# 1. Print the results of:
x is y
print("x value is:",x)
x is z
print("x value is:",x)
x == z
print("x value is:",x)
# Out:
# x value is: 10
# x value is: 10
# x value is: 10

# %%
# 2. Evaluate:
value1 = 2 + 3 * 4
print(value1)
value2 = (2 + 3) * 4
print(value2)
# Out:
# 14
# 20

# %% [markdown]
# Problem 6 : Operator Precedence Evaluation
#
# Topics: Precedence

# %%
# Evaluate and write the output:
x1 = 10 + 4 * 2
print(x1)

x2 = 100 / 10 + 5 * 3
print(x2)

x3 = 2 ** 3 * 2
print(x3)

x4 = (10 + 4) * 2
print(x4)
# Out:
# 18
# 25.0
# 16
# 28

# %% [markdown]
# Problem 7 : Associativity Challenge
#
# Topics: Associativity (Left → Right, Right → Left)

# %%
# Evaluate:
y1 = 5 - 2 - 1
print(y1)

y2 = 20 / 5 / 2
print(y2)

y3 = 2 ** 3 ** 2
print(y3)

y4 = (2 ** 3) ** 2
print(y4)
# Out:
# 2
# 2.0
# 512
# 64

# %% [markdown]
# Problem 8 : Circle Helper (Math Library & Type Casting)
#
# Topics: Math Functions, math Library, Type Casting

# %%
# Write a program that:
# 1. Asks the user to enter the radius of a circle (as text input).
r = input("enter the radius:")

# 2. Convert the radius to float.
r = float(r)
print(radius)
# Out:
# enter the radius: 10
# 10.0

# %%
# 3. Use the math library to calculate:
import math
π = math.pi
Area  = π * r * r
print("Area of the circle is:",Area)

Circumference = 2 * π * r
print("Circumference is :", Circumference)
# Out:
# Area of the circle is: 314.1592653589793
# Circumference is : 62.83185307179586

# %% [markdown]
# Problem 9 : Temperature Converter
#
# Topics: Type Casting, Mathematical Operators

# %%
# Write a program that:
# 1. Ask the user to enter a temperature in Celsius (as text input)
temp_C = input("enter the temperature in Celsius:")

#2. Convert it to float.
temp_C = float(temp_C)
print("temperature in Celsius:",temp_C)

#3. Convert it to Fahrenheit using:
temp_F = (temp_C * 9/5) + 32
print("temperature in Farenheit:",temp_F)
# Out:
# enter the temperature in Celsius: 40
# temperature in Celsius: 40.0
# temperature in Farenheit: 104.0

# %% [markdown]
# MCQ 10 : Operator Precedence & Logical Evaluation
#
# Topics: Logical Operators, Precedence

# %%
# What will be the output of:
5 > 3 and 2 + 4 == 6 or 10 < 5
# Out:
# True
